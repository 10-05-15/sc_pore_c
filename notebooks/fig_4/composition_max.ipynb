# %%
import numpy as np
import pandas as pd
import scipy.sparse as sp
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import gseapy as gp
from collections import defaultdict

plt.rcParams['figure.dpi'] = 200

CMAP = "#2563eb"

# %%
CN     = pd.read_csv("/home/jduhamel/sc_pore_c/notebooks/data/core_max_data/core_nodes_max_v2.csv")
CE     = pd.read_csv("/home/jduhamel/sc_pore_c/notebooks/data/core_max_data/core_edges_max_v2.csv")
H_core = sp.load_npz("/home/jduhamel/sc_pore_c/notebooks/data/core_max_data/H_core_max_v2.npz")   # rows = CN, cols = CE

print(f"CN: {len(CN)} core nodes")
print(f"CE: {len(CE)} core edges")
print(f"H_core: {H_core.shape}")
print(f"\nCN columns:  {CN.columns.tolist()}")
print(f"CE columns:  {CE.columns.tolist()}")
# Out:
# CN: 265 core nodes
# CE: 33131 core edges
# H_core: (265, 33131)
#
# CN columns:  ['bin_name', 'chrom', 'bin_start', 'bin_end', 'global_hge_max_unweighted', 'is_core']
# CE columns:  ['read_index', 'basename', 'mean_mapq', 'median_mapq', 'n_chromosomes', 'order', 'n_bins', 'read_length_bp', 'genes', 'n_genes']

# %%
def parse_genes(series):
    """Flatten a column of comma/semicolon-separated gene strings into a set."""
    genes = set()
    for val in series.dropna():
        for g in str(val).replace(";", ",").split(","):
            g = g.strip()
            if g and g != "nan":
                genes.add(g)
    return genes

# Genes overlapping core nodes (loci)
#cn_genes = parse_genes(CN["genes"])

# Genes overlapping core edges (reads) — usually richer
ce_genes = parse_genes(CE["genes"])

# Union
#all_core_genes = cn_genes | ce_genes
all_core_genes = ce_genes

#print(f"Genes in CN loci:       {len(cn_genes)}")
print(f"Genes in CE hyperedges: {len(ce_genes)}")
print(f"Union:                  {len(all_core_genes)}")
# Out:
# Genes in CE hyperedges: 5077
# Union:                  5077

# %%
# Map each CN row index to its chromosome
cn_chrom = CN["chrom"].values   # length = H_core.shape[0]

H_csc = H_core.tocsc()

edge_stats = []
for j in range(H_csc.shape[1]):
    col     = H_csc[:, j]
    members = col.nonzero()[0]           # CN row indices in this hyperedge
    chroms  = {str(c) for c in cn_chrom[members]}
    edge_stats.append({
        "edge_idx":    j,
        "n_nodes":     len(members),
        "n_chroms":    len(chroms),
        "chroms":      ",".join(sorted(chroms)),
        "is_inter":    len(chroms) > 1,
    })

edge_df = pd.DataFrame(edge_stats)

n_intra = (~edge_df["is_inter"]).sum()
n_inter = edge_df["is_inter"].sum()
print(f"Intra-chromosomal CE: {n_intra} ({100*n_intra/len(edge_df):.1f}%)")
print(f"Inter-chromosomal CE: {n_inter} ({100*n_inter/len(edge_df):.1f}%)")
# Out:
# Intra-chromosomal CE: 23837 (71.9%)
# Inter-chromosomal CE: 9294 (28.1%)

# %%
fig, ax = plt.subplots(figsize=(3, 3))

counts = [n_intra, n_inter]
labels = ["Intra", "Inter"]
colors = ["#2563eb", "#dc2626"]

ax.bar(labels, counts, color=colors, edgecolor="none", width=0.7)
ax.set_ylabel("Core edges", labelpad=8)
ax.set_title("Intra vs inter-chromosomal CE", pad=10, loc="center")
ax.spines[["top", "right"]].set_visible(False)
ax.tick_params(direction="in", length=4, width=0.8)

for i, v in enumerate(counts):
    ax.text(i, v + max(counts)*0.01, str(v), ha="center", fontsize=9)

plt.tight_layout()
#plt.savefig("core_intra_inter_bar.pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 4))

bins     = np.arange(2, 12)
intra    = edge_df[~edge_df["is_inter"]]["n_nodes"].values
inter    = edge_df[edge_df["is_inter"]]["n_nodes"].values
width    = 0.4

intra_counts = np.array([(intra == b).sum() for b in bins])
inter_counts = np.array([(inter == b).sum() for b in bins])

ax.bar(bins - width/2, intra_counts, width=width, color="#2563eb", label="Intra", edgecolor="none")
ax.bar(bins + width/2, inter_counts, width=width, color="#dc2626", label="Inter", edgecolor="none")

ax.set_xlabel("Hyperedge order (# CN nodes)", labelpad=8)
ax.set_ylabel("Count", labelpad=8)
ax.set_title("Hyperedge order by contact type", pad=10, loc="center")
ax.set_xlim(right=8)
ax.xaxis.set_major_locator(mticker.MultipleLocator(1))
ax.legend(frameon=False, fontsize=9)
ax.spines[["top", "right"]].set_visible(False)
ax.tick_params(direction="in", length=4, width=0.8)

plt.tight_layout()
plt.show()

# %%
inter_edges = edge_df[edge_df["is_inter"]]
chrom_pairs = defaultdict(int)
for _, row in inter_edges.iterrows():
    chroms = sorted(row["chroms"].split(","))
    for i in range(len(chroms)):
        for j in range(i+1, len(chroms)):
            chrom_pairs[(chroms[i], chroms[j])] += 1

all_chroms = sorted(
    [str(c) for c in CN["chrom"].unique()],
    key=lambda x: int(x.replace("chr", "")) if x.replace("chr", "").isdigit() else 100
)
n_chr = len(all_chroms)
chrom_idx = {c: i for i, c in enumerate(all_chroms)}
mat = np.zeros((n_chr, n_chr))
for (a, b), cnt in chrom_pairs.items():
    if a in chrom_idx and b in chrom_idx:
        i, j = chrom_idx[a], chrom_idx[b]
        mat[i, j] = cnt
        mat[j, i] = cnt

# %%
fig, ax = plt.subplots(figsize=(5, 4))

sns.heatmap(
    mat,
    cmap="YlOrBr",
    square=True,
    xticklabels=all_chroms,
    yticklabels=all_chroms,
    linewidths=0,
    cbar_kws={"shrink": 0.5, "label": "# inter-chr CE"},
    ax=ax,
)
ax.set_title("Inter-chromosomal CE pairs", pad=10, loc="left")
ax.tick_params(labelsize=7, length=2)

plt.tight_layout()
#plt.savefig("core_interchrom_heatmap.pdf", bbox_inches="tight")
plt.show()

# %%
LIBRARIES = [
    "KEGG_2019_Mouse",
    "GO_Biological_Process_2023",
    "Reactome_2022",
    "MSigDB_Hallmark_2020",
]

gene_list = sorted(all_core_genes)
print(f"Submitting {len(gene_list)} genes to Enrichr...")

enr_results = {}
for lib in LIBRARIES:
    enr = gp.enrichr(
        gene_list=gene_list,
        gene_sets=lib,
        organism="mouse",
        outdir=None,
        verbose=False,
    )
    enr_results[lib] = enr.results
    sig = enr.results[enr.results["Adjusted P-value"] < 0.05]
    print(f"  {lib}: {len(sig)} significant terms")
# Out:
# Submitting 5077 genes to Enrichr...
#   KEGG_2019_Mouse: 0 significant terms
#   GO_Biological_Process_2023: 0 significant terms
#   Reactome_2022: 0 significant terms
#   MSigDB_Hallmark_2020: 0 significant terms

# %%
N_TERMS = 15

for lib, df in enr_results.items():
    df = df[df["Adjusted P-value"] < 0.05].copy()
    if df.empty:
        print(f"No significant terms: {lib}")
        continue

    df["-log10(FDR)"] = -np.log10(df["Adjusted P-value"].clip(lower=1e-300))
    df = df.nsmallest(N_TERMS, "Adjusted P-value")

    fig, ax = plt.subplots(figsize=(7, max(3, len(df) * 0.35)))
    ax.barh(df["Term"], df["-log10(FDR)"], color=CMAP, edgecolor="none")
    ax.axvline(-np.log10(0.05), color="black", lw=0.8, ls="--", label="FDR=0.05")
    ax.set_xlabel("-log10(FDR)", labelpad=8)
    ax.set_title(lib.replace("_", " "), pad=10, loc="left")
    ax.invert_yaxis()
    ax.spines[["top","right"]].set_visible(False)
    ax.tick_params(labelsize=8)
    ax.legend(frameon=False, fontsize=8)
    plt.tight_layout()
    plt.savefig(f"gsea_{lib}.pdf", bbox_inches="tight")
    plt.show()
# Out:
# No significant terms: KEGG_2019_Mouse
# No significant terms: GO_Biological_Process_2023
# No significant terms: Reactome_2022
# No significant terms: MSigDB_Hallmark_2020

# %%
# Load a TF gene list 
# with open("tf_list.txt") as f:
#     tf_set = {l.strip() for l in f if l.strip()}

tf_set = set()   # placeholder

#cn_tfs  = cn_genes  & tf_set
ce_tfs  = ce_genes  & tf_set
all_tfs = all_core_genes & tf_set

#print(f"TFs in CN loci:       {len(cn_tfs)}")
print(f"TFs in CE hyperedges: {len(ce_tfs)}")
print(f"Union:                {len(all_tfs)}")
print(f"\nTFs found:\n{sorted(all_tfs)}")
# Out:
# TFs in CE hyperedges: 0
# Union:                0
#
# TFs found:
# []

# %%
if all_tfs:
    # Which chromosomes do TF-containing CN loci sit on?
    tf_cn = CN[CN["genes"].apply(
        lambda x: bool(parse_genes(pd.Series([x])) & tf_set) if pd.notna(x) else False
    )]

    tf_per_chrom = tf_cn.groupby("chrom").size().reindex(all_chroms, fill_value=0)

    fig, ax = plt.subplots(figsize=(10, 3.5))
    ax.bar(tf_per_chrom.index, tf_per_chrom.values, color=CMAP, edgecolor="none")
    ax.set_xlabel("Chromosome", labelpad=8)
    ax.set_ylabel("TF-containing CN loci", labelpad=8)
    ax.set_title("TF distribution across core nodes", pad=10, loc="left")
    ax.spines[["top","right"]].set_visible(False)
    ax.tick_params(axis="x", rotation=45, labelsize=8)
    plt.tight_layout()
    plt.savefig("core_tf_distribution.pdf", bbox_inches="tight")
    plt.show()
else:
    print("Load a TF list in Cell 6 first.")
# Out:
# Load a TF list in Cell 6 first.

# %%
import time
import scanpy as sc
import os
import sys
source_path = os.path.abspath("../utilities/")
sys.path.append(source_path)
import matrix as matrix

# %%
anndata_path    = "/nfs/turbo/umms-indikar/shared/projects/poreC/pipeline_outputs/higher_order/anndata/"
singlecell_path = anndata_path + "singlecell_mESC_1000000_features.h5ad"

t0 = time.time()
bdata = sc.read_h5ad(singlecell_path)
print(f"Loaded in {time.time()-t0:.1f}s"); sc.logging.print_memory_usage()
print(bdata)
# Out:
# Loaded in 287.1s
# Memory usage: current 55.57 GB, difference +26.85 GB
# AnnData object with n_obs × n_vars = 2579 × 32545444
#     obs: 'bin_index', 'bin_start', 'bin_end', 'bin', 'chrom', 'chrom_bin', 'degree', 'genes', 'n_genes', 'ATACSeq_1', 'ATACSeq_2', 'ATACSeq_3', 'CTCF', 'H3K27ac', 'H3K27me3', 'RNA_1', 'RNA_2', 'RNA_3', 'RNA_4', 'RNA_5', 'RNA_6', 'PolII'
#     var: 'read_index', 'basename', 'mean_mapq', 'median_mapq', 'n_chromosomes', 'order', 'n_bins', 'read_length_bp', 'genes', 'n_genes'
#     uns: 'base_resolution', 'chrom_sizes', 'gdf', 'gene_map', 'intervals'
#     layers: 'H'
# /nfs/turbo/umms-indikar/Joseph/conda_envs/pore_c/lib/python3.13/site-packages/anndata/logging.py:57: FutureWarning: The specified parameters ('newline',) are no longer positional. Please specify them like `newline=False`
#   print(format_memory_usage(get_memory_usage(), msg, newline))

# %%
def find_outliers_iqr(col):
    Q1, Q3 = col.quantile(0.15), col.quantile(0.85)
    IQR = Q3 - Q1
    return (col < Q1 - 1.5*IQR) | (col > Q3 + 1.5*IQR)

# %%
bdata.obs['degree_outlier'] = find_outliers_iqr(bdata.obs['degree'])
outliers = bdata.obs[bdata.obs['degree_outlier']].index.to_list()
print(f"Outlier loci: {len(outliers)}")

matrix.expand_and_normalize_anndata(bdata, oe_kr=False)

B = bdata.obsm['A']
B = B.drop(outliers, axis=0).drop(outliers, axis=1)
print(f"Contact matrix shape: {B.shape}")
# Out:
# Outlier loci: 21
# Expanding input matrix...
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[108], line 5
#       2 outliers = bdata.obs[bdata.obs['degree_outlier']].index.to_list()
#       3 print(f"Outlier loci: {len(outliers)}")
# ----> 5 matrix.expand_and_normalize_anndata(bdata, oe_kr=False)
#       7 B = bdata.obsm['A']
#       8 B = B.drop(outliers, axis=0).drop(outliers, axis=1)
#
# File ~/sc_pore_c/notebooks/utilities/matrix.py:27, in expand_and_normalize_anndata(adata, unique_only, oe_kr)
#      14 """
#      15 Expands the input matrix and applies KR and OE normalization.
#      16
#    (...)     23     None
#      24 """
#      26 print("Expanding input matrix...")
# ---> 27 H = adata.to_df()
#      29 if unique_only:
#      30     H = H.T.drop_duplicates().T
#
# File /nfs/turbo/umms-indikar/Joseph/conda_envs/pore_c/lib/python3.13/site-packages/anndata/_core/anndata.py:1276, in AnnData.to_df(self, layer)
#    1274     X = self.X
#    1275 if issparse(X):
# -> 1276     X = X.toarray()
#    1277 return pd.DataFrame(X, index=self.obs_names, columns=self.var_names)
#
# File /nfs/turbo/umms-indikar/Joseph/conda_envs/pore_c/lib/python3.13/site-packages/scipy/sparse/_compressed.py:996, in _cs_matrix.toarray(self, order, out)
#     994 if out is None and order is None:
#     995     order = self._swap('cf')[0]
# --> 996 out = self._process_toarray_args(order, out)
#     997 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#     998     raise ValueError('Output array must be C or F contiguous')
#
# File /nfs/turbo/umms-indikar/Joseph/conda_envs/pore_c/lib/python3.13/site-packages/scipy/sparse/_base.py:1530, in _spbase._process_toarray_args(self, order, out)
#    1528     return out
#    1529 else:
# -> 1530     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 625. GiB for an array with shape (2579, 32545444) and data type int64

# %%
# chromosome for each locus (from bdata.obs, aligned to B index after outlier drop)
locus_obs = bdata.obs.drop(outliers)
locus_chrom = locus_obs["chrom"].values
locus_names = locus_obs.index.values

B_arr = B.values

all_chroms = sorted(
    locus_obs["chrom"].unique(),
    key=lambda x: int(x.replace("chr","")) if x.replace("chr","").isdigit() else 100
)
chrom_idx = {c: i for i, c in enumerate(all_chroms)}
n_chr     = len(all_chroms)

# Sum contacts into chromosome-pair bins
chrom_mat = np.zeros((n_chr, n_chr))
for i, ci in enumerate(locus_chrom):
    for j, cj in enumerate(locus_chrom):
        if B_arr[i, j] > 0:
            chrom_mat[chrom_idx[ci], chrom_idx[cj]] += B_arr[i, j]

# Symmetrise (should already be, just in case)
chrom_mat = (chrom_mat + chrom_mat.T) / 2

intra_total = np.diag(chrom_mat).sum()
inter_total = chrom_mat.sum() - intra_total
print(f"Intra-chromosomal contact mass: {intra_total:.0f} ({100*intra_total/(intra_total+inter_total):.1f}%)")
print(f"Inter-chromosomal contact mass: {inter_total:.0f} ({100*inter_total/(intra_total+inter_total):.1f}%)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 6
#       3 locus_chrom = locus_obs["chrom"].values
#       4 locus_names = locus_obs.index.values
# ----> 6 B_arr = B.values
#       8 all_chroms = sorted(
#       9     locus_obs["chrom"].unique(),
#      10     key=lambda x: int(x.replace("chr","")) if x.replace("chr","").isdigit() else 100
#      11 )
#      12 chrom_idx = {c: i for i, c in enumerate(all_chroms)}
#
# NameError: name 'B' is not defined

# %%
fig, ax = plt.subplots(figsize=(4, 4))

counts = [intra_total, inter_total]
labels = ["Intra", "Inter"]
colors = ["#2563eb", "#dc2626"]

ax.bar(labels, counts, color=colors, edgecolor="none", width=0.5)
ax.set_ylabel("Total contact mass", labelpad=8)
ax.set_title("Single cells — intra vs inter-chromosomal", pad=10, loc="left")
ax.spines[["top", "right"]].set_visible(False)
ax.tick_params(direction="in", length=4, width=0.8)
ax.yaxis.set_major_formatter(mticker.ScalarFormatter(useMathText=True))
ax.ticklabel_format(style="sci", axis="y", scilimits=(0,0))

plt.tight_layout()
#plt.savefig("sc_intra_inter_bar.pdf", bbox_inches="tight")
plt.show()

# %%
# Zero out diagonal for inter-only view
inter_mat = chrom_mat.copy()
np.fill_diagonal(inter_mat, 0)

fig, ax = plt.subplots(figsize=(7, 6))
sns.heatmap(
    inter_mat,
    cmap="YlOrBr",
    square=True,
    xticklabels=all_chroms,
    yticklabels=all_chroms,
    linewidths=0,
    cbar_kws={"shrink": 0.5, "label": "Contact mass (log1p)"},
    norm=plt.matplotlib.colors.LogNorm(
        vmin=inter_mat[inter_mat > 0].min(),
        vmax=inter_mat.max()
    ),
    ax=ax,
)
ax.set_title("Single cells — inter-chromosomal contacts", pad=10, loc="left")
ax.tick_params(labelsize=7, length=2)
plt.tight_layout()
plt.savefig("sc_interchrom_heatmap.pdf", bbox_inches="tight")
plt.show()
